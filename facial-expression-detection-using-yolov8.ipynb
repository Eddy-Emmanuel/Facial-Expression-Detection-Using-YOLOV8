# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.3/721.3 kB 12.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import os
import numpy as np
import pandas as pd

import yaml
from ultralytics import YOLO

# %%
pretrained_model = YOLO(model='yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 74.1MB/s]

# %%
pretrained_model.train(data="/kaggle/input/affectnet-yolo-format/YOLO_format/data.yaml", 
                      epochs=20,
                      batch=32,
                      imgsz=640)
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# ## Eddy
